# %% [markdown]
# # MockUp für Funktionen der Website

# %%
# %pip install -q -r requirements.txt

# %%
MockupJSON = "GUI-MockUp-JSON.svg"
MockupManuell = "GUI-MockUp-Manuell.svg"

from IPython.display import SVG, display
def show_svg(svgContent):
    display(SVG(svgContent))

# %%
show_svg(MockupJSON)

# %%
show_svg(MockupManuell)
